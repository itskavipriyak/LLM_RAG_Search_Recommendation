# %%
# !pip install "langchain[unstructured]" pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.6.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain[unstructured]
#   Downloading langchain-1.2.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.2.7 (from langchain[unstructured])
#   Downloading langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph<1.1.0,>=1.0.7 (from langchain[unstructured])
#   Downloading langgraph-1.0.7-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain[unstructured]) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading langsmith-0.6.6-py3-none-any.whl.metadata (15 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured]) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading uuid_utils-0.14.0-cp39-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading langgraph_checkpoint-4.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.7 (from langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading langgraph_prebuilt-1.0.7-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading langgraph_sdk-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (0.28.1)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured])
#   Downloading orjson-3.11.6-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (1.0.9)
# Requirement already satisfied: idna in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain[unstructured]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[unstructured]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[unstructured]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[unstructured]) (0.4.2)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain[unstructured])
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Downloading langchain-1.2.7-py3-none-any.whl (108 kB)
# Downloading langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.7-py3-none-any.whl (157 kB)
# Downloading langgraph_checkpoint-4.0.0-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.7-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.3-py3-none-any.whl (67 kB)
# Downloading langsmith-0.6.6-py3-none-any.whl (308 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.14.0-cp39-abi3-win_amd64.whl (182 kB)
# Downloading pypdf-6.6.2-py3-none-any.whl (329 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.6-cp312-cp312-win_amd64.whl (136 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, tenacity, pyyaml, pypdf, packaging, ormsgpack, orjson, jsonpointer, charset_normalizer, requests, jsonpatch, requests-toolbelt, langgraph-sdk, langsmith, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ----- ----------------------------------  3/22 [urllib3]
#    --------- ------------------------------  5/22 [pyyaml]
#    ---------- -----------------------------  6/22 [pypdf]
#    ---------- -----------------------------  6/22 [pypdf]
#   Attempting uninstall: packaging
#    ---------- -----------------------------  6/22 [pypdf]
#     Found existing installation: packaging 26.0
#    ---------- -----------------------------  6/22 [pypdf]
#     Uninstalling packaging-26.0:
#    ---------- -----------------------------  6/22 [pypdf]
#       Successfully uninstalled packaging-26.0
#    ---------- -----------------------------  6/22 [pypdf]
#    ---------------- -----------------------  9/22 [orjson]
#    --------------------- ------------------ 12/22 [requests]
#    --------------------------- ------------ 15/22 [langgraph-sdk]
#    ----------------------------- ---------- 16/22 [langsmith]
#    ----------------------------- ---------- 16/22 [langsmith]
#    ----------------------------- ---------- 16/22 [langsmith]
#    ----------------------------- ---------- 16/22 [langsmith]
#    ----------------------------- ---------- 16/22 [langsmith]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ------------------------------ --------- 17/22 [langchain-core]
#    ---------------------------------- ----- 19/22 [langgraph-prebuilt]
#    ------------------------------------ --- 20/22 [langgraph]
#    ------------------------------------ --- 20/22 [langgraph]
#    -------------------------------------- - 21/22 [langchain]
#    ---------------------------------------- 22/22 [langchain]
#
# Successfully installed charset_normalizer-3.4.4 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.2.7 langchain-core-1.2.7 langgraph-1.0.7 langgraph-checkpoint-4.0.0 langgraph-prebuilt-1.0.7 langgraph-sdk-0.3.3 langsmith-0.6.6 orjson-3.11.6 ormsgpack-1.12.2 packaging-25.0 pypdf-6.6.2 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 tenacity-9.1.2 urllib3-2.6.3 uuid-utils-0.14.0 xxhash-3.6.0 zstandard-0.25.0
# WARNING: langchain 1.2.7 does not provide the extra 'unstructured'
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (1.2.7)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.46-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (0.6.6)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain_community) (2.4.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.6)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.3.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 989.2 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.8 MB/s eta 0:00:00
# Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp312-cp312-win_amd64.whl (46 kB)
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading sqlalchemy-2.0.46-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.5 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading greenlet-3.3.1-cp312-cp312-win_amd64.whl (227 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Installing collected packages: propcache, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
#
#    ---- -----------------------------------  2/19 [multidict]
#    ------ ---------------------------------  3/19 [marshmallow]
#    ---------- -----------------------------  5/19 [greenlet]
#    ---------- -----------------------------  5/19 [greenlet]
#    -------------- -------------------------  7/19 [attrs]
#    -------------- -------------------------  7/19 [attrs]
#    ------------------ ---------------------  9/19 [yarl]
#    --------------------- ------------------ 10/19 [typing-inspect]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ----------------------- ---------------- 11/19 [SQLAlchemy]
#    ------------------------- -------------- 12/19 [aiosignal]
#    --------------------------- ------------ 13/19 [pydantic-settings]
#    ----------------------------- ---------- 14/19 [dataclasses-json]
#    ------------------------------- -------- 15/19 [aiohttp]
#    ------------------------------- -------- 15/19 [aiohttp]
#    ------------------------------- -------- 15/19 [aiohttp]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ----------------------------------- ---- 17/19 [langchain-classic]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ------------------------------------- -- 18/19 [langchain_community]
#    ---------------------------------------- 19/19 [langchain_community]
#
# Successfully installed SQLAlchemy-2.0.46 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 attrs-25.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.3.1 httpx-sse-0.4.3 langchain-classic-1.0.1 langchain-text-splitters-1.1.0 langchain_community-0.4.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.12.0 typing-inspect-0.9.0 yarl-1.22.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install Unstructured
# Out:
# Collecting Unstructured
#   Downloading unstructured-0.18.31-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset-normalizer in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (3.4.4)
# Collecting filetype (from Unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from Unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from Unstructured)
#   Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting nltk (from Unstructured)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (2.32.5)
# Collecting beautifulsoup4 (from Unstructured)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from Unstructured)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (0.6.7)
# Collecting python-iso639 (from Unstructured)
#   Downloading python_iso639-2025.11.16-py3-none-any.whl.metadata (15 kB)
# Collecting langdetect (from Unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 15.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (2.4.1)
# Collecting rapidfuzz (from Unstructured)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from Unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (4.15.0)
# Collecting unstructured-client (from Unstructured)
#   Downloading unstructured_client-0.42.8-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from Unstructured)
#   Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from Unstructured) (7.2.2)
# Collecting python-oxmsg (from Unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from Unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting numba (from Unstructured)
#   Downloading numba-0.63.1-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->Unstructured)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from dataclasses-json->Unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from dataclasses-json->Unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->Unstructured) (25.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->Unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from html5lib->Unstructured) (1.17.0)
# Collecting webencodings (from html5lib->Unstructured)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting click (from nltk->Unstructured)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk->Unstructured)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk->Unstructured)
#   Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: colorama in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from click->nltk->Unstructured) (0.4.6)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba->Unstructured)
#   Downloading llvmlite-0.46.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting numpy (from Unstructured)
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting olefile (from python-oxmsg->Unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from requests->Unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from requests->Unstructured) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from requests->Unstructured) (2026.1.4)
# Collecting aiofiles>=24.1.0 (from unstructured-client->Unstructured)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting cryptography>=3.1 (from unstructured-client->Unstructured)
#   Downloading cryptography-46.0.4-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured-client->Unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured-client->Unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured-client->Unstructured) (2.12.5)
# Requirement already satisfied: pypdf>=6.2.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured-client->Unstructured) (6.6.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured-client->Unstructured) (1.0.0)
# Collecting cffi>=2.0.0 (from cryptography>=3.1->unstructured-client->Unstructured)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->Unstructured)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpcore>=1.0.9->unstructured-client->Unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->Unstructured) (4.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic>=2.11.2->unstructured-client->Unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic>=2.11.2->unstructured-client->Unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from pydantic>=2.11.2->unstructured-client->Unstructured) (0.4.2)
# Downloading unstructured-0.18.31-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 19.7 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    --------------------------------------- 608.4/608.4 kB 11.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 30.0 MB/s eta 0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 26.6 MB/s eta 0:00:00
# Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl (277 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading numba-0.63.1-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 31.9 MB/s eta 0:00:00
# Downloading llvmlite-0.46.0-cp312-cp312-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    -------- ------------------------------- 8.4/38.1 MB 40.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 16.3/38.1 MB 37.9 MB/s eta 0:00:01
#    ------------------------ --------------- 23.3/38.1 MB 36.0 MB/s eta 0:00:01
#    -------------------------------- ------- 31.5/38.1 MB 37.0 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.1 MB 36.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.1 MB 36.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 28.5 MB/s eta 0:00:00
# Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------------------------- -------------- 8.1/12.8 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 34.8 MB/s eta 0:00:00
# Downloading python_iso639-2025.11.16-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 27.2 MB/s eta 0:00:00
# Downloading unstructured_client-0.42.8-py3-none-any.whl (219 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading cryptography-46.0.4-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 3.5/3.5 MB 29.2 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl (60 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993367 sha256=caba40d11cc3609d435e575bc4fc9ebaec92ea904e7841bf1ecce0496ed413f3
#   Stored in directory: c:\users\sakth\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: webencodings, filetype, wrapt, soupsieve, regex, rapidfuzz, python-magic, python-iso639, pycparser, olefile, numpy, lxml, llvmlite, langdetect, joblib, html5lib, emoji, click, backoff, aiofiles, python-oxmsg, numba, nltk, cffi, beautifulsoup4, cryptography, unstructured-client, Unstructured
#
#    ---- -----------------------------------  3/28 [soupsieve]
#    ------- --------------------------------  5/28 [rapidfuzz]
#    ------- --------------------------------  5/28 [rapidfuzz]
#    ------------ ---------------------------  9/28 [olefile]
#   Attempting uninstall: numpy
#    ------------ ---------------------------  9/28 [olefile]
#     Found existing installation: numpy 2.4.1
#    ------------ ---------------------------  9/28 [olefile]
#    -------------- ------------------------- 10/28 [numpy]
#     Uninstalling numpy-2.4.1:
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#       Successfully uninstalled numpy-2.4.1
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    -------------- ------------------------- 10/28 [numpy]
#    --------------- ------------------------ 11/28 [lxml]
#    --------------- ------------------------ 11/28 [lxml]
#    --------------- ------------------------ 11/28 [lxml]
#    ----------------- ---------------------- 12/28 [llvmlite]
#    ----------------- ---------------------- 12/28 [llvmlite]
#    ----------------- ---------------------- 12/28 [llvmlite]
#    ----------------- ---------------------- 12/28 [llvmlite]
#    ----------------- ---------------------- 12/28 [llvmlite]
#    -------------------- ------------------- 14/28 [joblib]
#    -------------------- ------------------- 14/28 [joblib]
#    --------------------- ------------------ 15/28 [html5lib]
#    ------------------------ --------------- 17/28 [click]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------ --------- 21/28 [numba]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ---------------------------------- ----- 24/28 [beautifulsoup4]
#    ----------------------------------- ---- 25/28 [cryptography]
#    ----------------------------------- ---- 25/28 [cryptography]
#    ------------------------------------- -- 26/28 [unstructured-client]
#    ------------------------------------- -- 26/28 [unstructured-client]
#    ------------------------------------- -- 26/28 [unstructured-client]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    -------------------------------------- - 27/28 [Unstructured]
#    ---------------------------------------- 28/28 [Unstructured]
#
# Successfully installed Unstructured-0.18.31 aiofiles-25.1.0 backoff-2.2.1 beautifulsoup4-4.14.3 cffi-2.0.0 click-8.3.1 cryptography-46.0.4 emoji-2.15.0 filetype-1.2.0 html5lib-1.1 joblib-1.5.3 langdetect-1.0.9 llvmlite-0.46.0 lxml-6.0.2 nltk-3.9.2 numba-0.63.1 numpy-2.3.5 olefile-0.47 pycparser-3.0 python-iso639-2025.11.16 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.14.3 regex-2026.1.15 soupsieve-2.8.3 unstructured-client-0.42.8 webencodings-0.5.1 wrapt-2.0.1
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install unstructured_pytesseract
# Out:
# Requirement already satisfied: unstructured_pytesseract in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (0.3.15)
# Requirement already satisfied: packaging>=21.3 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured_pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\sakth\pycharmmiscproject\.venv\lib\site-packages (from unstructured_pytesseract) (12.1.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import UnstructuredImageLoader
import pytesseract
from PIL import Image
import os

file_path = "commerical.jpg"
# os.environ["TESSERACT_CMD"]=r"C:\Program Files\Tesseract-OCR\tesseract.exe"
# pytesseract.pytesseract.tesseract_cmd=r'C:\Users\sakth\PyCharmMiscProject\.venv\Scripts\pytesseract.exe'
# print(pytesseract.image_to_string(Image.open('commerical.jpg')))
# pytesseract.pytesseract.tesseract_cmd=r"C:\Program Files\Tesseract-OCR\tesseract.exe"
loader = UnstructuredImageLoader(file_path)
#
# # Load the document
documents = loader.load()
#
# # The image content (text extracted via OCR) will be in the page_content of the document
print(documents[0].page_content)
# Out:
# Warning: No languages specified, defaulting to English.
# Summarize all the Commercial Agencies registration in a table while providing the commercial agency, its country, representative in Kuwait, agency registration number, and dates
#
# Show thinking ¥
#
# Based on the Official Gazette of Kuwait (Kuwait Al Your), Issue No. 1674, the following Commercial Agencies registrations were announced:
#
# Commercial Agencies registrations were announced: ‘Commercial Agency Dogusan Insaat Ticaret AS. Bendalis GmbH Chibueze Tip Top Desert World Petroleum Services Company Ningbo Land Link Industrial Technology Company Limited Diirr Dental Adelphi Manufacturing Company Limited Ultazonic NV Company Ferrovab (FZE) International Company for Consumer Goods and Food Factory Rudolph Research Analytical Company Kayalar Group for Energy Drinks Industry and Trade Dr. Schumacher Jinan Meide Casting Country _Representative in Kuwait Registration _Dates (Term) No. Turkey CAM International Group 00140 /2024 17/12/2023 - for Marketing, General 1612/2026 Trading and Contracting Company Germany MedCareGeneral Trading 0136/2024 24/11/2023 - ‘Company 231172025 USA Moncada Export and 0013712024 31/08/2023 - Import Company 3108/2025 Jordan __Al-Safat Gulf Foodstuff 00106 /2024 _30/12023 - ‘Company 29nv2024 Egypt Khaf General Trading and 00125 /2024 02/2023 - Contracting Company 0v02/2028 China Shaalan KuwaitiCompany 0139/2024 23/09/2023 ~ for Electrical Tools and 23/09/2028 Contracting Germany Cura Health Company 0013872024 14/11/2023 - 131172025 UK Taqaddum Al-Khalee} 2024/00154 08/01/2024 - Trading Company 3122027 Belgium —_Tagaddum Al-Khaleej 2024/0153 0102/2023 - Trading Company 3112/2025 UAE Gas and Oil Field Services 2024/0151 10/12/2023 - ‘Company / GOFSCO 09/12/2025 Saudi Al-Zahim & Malhotra 2024/0146 012023 - Arabia General Trading Company 3110/2024 USA Tecton Electronic 2024/00155 26/07/2022 - Appliances Company 26/07/2027 Turkey Kuwait Eagle Foodstuff 2023/01682 05/12/2022 - Retail Company 0412/2025 Germany _Al-Owais International 2024/00152 10/10/2023 - General Trading Company 10/10/2026 China 2024/0147 07/09/2023 ~
#
# Co., Ltd.
#
# General Trading and Contracting Company
#
# 3112/2026
#
# Devicor Medical
#
# Products, Inc.
#
# USA
#
# Alshaya Healthcare Company
#
# 2024/00117 04/10/2022 -
#
# 3112/2025
#
# ‘Stratus Medical LLC
#
# USA
#
# Alshaya Healthcare Company
#
# 2024/00128 19/09/2023 -
#
# 3112/2025
#
# HR Exports
#
# India
#
# Tabarak United Foodstuff, 2024/00159 12/09/2023 - Vegetables and Fruits ‘Company
#
# 1709/2024

# %%
ocr_doc=documents[0].page_content

# %%
print(documents[0].metadata)
# Out:
# {'source': 'commerical.jpg'}

# %%
from pathlib import Path
from typing import List, Any
from langchain_community.document_loaders import PyPDFLoader, TextLoader, CSVLoader
from langchain_community.document_loaders.word_document import Docx2txtLoader
from langchain_community.document_loaders.excel import UnstructuredExcelLoader
from langchain_community.document_loaders import JSONLoader
from langchain_community.document_loaders import UnstructuredImageLoader



def load_all_documents(data_dir: str) -> List[Any]:
    """
    Load all supported files from the data directory and convert to LangChain document structure.
    Supported: PDF, TXT, CSV, Excel, Word, JSON
    """
    # Use project root data folder
    data_path = Path(data_dir).resolve()
    print(f"[DEBUG] Data path: {data_path}")
    documents = []

    # PDF files
    pdf_files = list(data_path.glob('**/*.pdf'))
    print(f"[DEBUG] Found {len(pdf_files)} PDF files: {[str(f) for f in pdf_files]}")
    for pdf_file in pdf_files:
        print(f"[DEBUG] Loading PDF: {pdf_file}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} PDF docs from {pdf_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load PDF {pdf_file}: {e}")

    # TXT files
    txt_files = list(data_path.glob('**/*.txt'))
    print(f"[DEBUG] Found {len(txt_files)} TXT files: {[str(f) for f in txt_files]}")
    for txt_file in txt_files:
        print(f"[DEBUG] Loading TXT: {txt_file}")
        try:
            loader = TextLoader(str(txt_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} TXT docs from {txt_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load TXT {txt_file}: {e}")

    # CSV files
    csv_files = list(data_path.glob('**/*.csv'))
    print(f"[DEBUG] Found {len(csv_files)} CSV files: {[str(f) for f in csv_files]}")
    for csv_file in csv_files:
        print(f"[DEBUG] Loading CSV: {csv_file}")
        try:
            loader = CSVLoader(str(csv_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} CSV docs from {csv_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load CSV {csv_file}: {e}")

    # Excel files
    xlsx_files = list(data_path.glob('**/*.xlsx'))
    print(f"[DEBUG] Found {len(xlsx_files)} Excel files: {[str(f) for f in xlsx_files]}")
    for xlsx_file in xlsx_files:
        print(f"[DEBUG] Loading Excel: {xlsx_file}")
        try:
            loader = UnstructuredExcelLoader(str(xlsx_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} Excel docs from {xlsx_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load Excel {xlsx_file}: {e}")

    # Word files
    docx_files = list(data_path.glob('**/*.docx'))
    print(f"[DEBUG] Found {len(docx_files)} Word files: {[str(f) for f in docx_files]}")
    for docx_file in docx_files:
        print(f"[DEBUG] Loading Word: {docx_file}")
        try:
            loader = Docx2txtLoader(str(docx_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} Word docs from {docx_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load Word {docx_file}: {e}")

    # JSON files
    json_files = list(data_path.glob('**/*.json'))
    print(f"[DEBUG] Found {len(json_files)} JSON files: {[str(f) for f in json_files]}")
    for json_file in json_files:
        print(f"[DEBUG] Loading JSON: {json_file}")
        try:
            loader = JSONLoader(str(json_file))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} JSON docs from {json_file}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load JSON {json_file}: {e}")

    # print(f"[DEBUG] Total loaded documents: {len(documents)}")
    # return documents

    # JPG files
    jpg_files = list(data_path.glob('**/*.jpg'))
    print(f"[DEBUG] Found {len(jpg_files)} JPG files: {[str(f) for f in jpg_files]}")
    for jpg_files in jpg_files:
        print(f"[DEBUG] Loading JPG: {jpg_files}")
        try:
            loader = UnstructuredImageLoader(str(jpg_files))
            loaded = loader.load()
            print(f"[DEBUG] Loaded {len(loaded)} JPG docs from {jpg_files}")
            documents.extend(loaded)
        except Exception as e:
            print(f"[ERROR] Failed to load JPG {jpg_files}: {e}")

    print(f"[DEBUG] Total loaded documents: {len(documents)}")
    return documents

# Example usage
if __name__ == "__main__":
    docs = load_all_documents("data")
    print(f"Loaded {len(docs)} documents.")
    print("Example document:", docs[0] if docs else None)
# Out:
# [DEBUG] Data path: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data
# [DEBUG] Found 2 PDF files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Kavipriya Kandavel - AIML Engineer_2025.pdf', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Vijayalakshmi-Aadhaar.pdf']
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loaded 5 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Loaded 1 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Found 0 TXT files: []
# [DEBUG] Found 0 CSV files: []
# [DEBUG] Found 0 Excel files: []
# [DEBUG] Found 1 Word files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\zData Scientist Job Description.docx']
# [DEBUG] Loading Word: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx
# [ERROR] Failed to load Word C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx: No module named 'docx2txt'
# [DEBUG] Found 0 JSON files: []
# [DEBUG] Found 2 JPG files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\commerical.jpg', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\decisions.jpg']
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# [DEBUG] Total loaded documents: 8
# Loaded 8 documents.
# Example document: page_content='C e r t i f i c a t i o n s  a n d  C o u r s e s
# P G P  i n  A r t i f i c i a l  I n t e l l i g e n c e  &  M a c h i n e
# L e a r n i n g .
# O r a c l e  C e r t i f i e d  P L / S Q L  A s s o c i a t e  &
# P r o f e s s i o n a l
# S u n  C e r t i f i e d  J A V A  p r o g r a m m e r
# T a b l e a u  &  P y t h o n  C e r t i f i e d  p r o g r a m m e r
# A s s i s t a n t  V i c e  P r e s i d e n t  -  S e n i o r  S o f t w a r e  E n g i n e e r   I I I
# B A  C o n t i n u u m  I n d i a  P v t .  L t d .
# M a y  2 0 2 2  -  M a r c h  2 0 2 5
# A I / M L  b a s e d  P r o j e c t s :
# D a t a  L a b e l l i n g  / a n n o t a t i o n ,  p r e p a r a t i o n  o f  a n n o t a t i o n  s h e e t  f o r  c o m p a r i n g  t h e
# e x t r a c t e d  r e s u l t s .  L a b e l  S t u d i o  w a s  u s e d  t o  l a b e l  a n d  a n n o t a t e  t h e  d a t a .
# E x t r a c t  t h e  t e x t  f r o m  t h e  s t r u c t u r e d / u n s t r u c t u r e d  t a b l e  f r o m  t h e  d o c u m e n t
# M e n t o r  t h e  t e a m  a n d  p a r t i c i p a t e d  i n  K a g g l e ’ s  “ W o m e n  i n  D a t a  S c i e n c e ”
# p r o g r a m  -  “ E q u i t y  i n  H e a l t h c a r e ” .  E x p e r i m e n t e d  w i t h  v a r i o u s  M L  m o d e l s  l i k e
# l o g i s t i c  R e g r e s s i o n  a n d  b o o s t i n g  a l g o r i t h m s  l i k e  X G B o o s t ,  G r a d i e n t
# B o o s t i n g ,   A d a B o o s t  a n d  C a t B o o s t .
# S u m m a r y
#  I T  p r o f e s s i o n a l  w i t h  1 7  y e a r s  o f
# e x p e r i e n c e  i n  p r o d u c t  d e v e l o p m e n t  o n
# C r e d i t  C a r d  d o m a i n  a n d  r e a l - t i m e  M a c h i n e
# L e a r n i n g  i n t e g r a t i o n .   P r o f i c i e n t  i n  l e a d i n g
# a n d  m e n t o r i n g  c r o s s - f u n c t i o n a l  t e a m s  t o
# p l a n ,  b u i l d  a n d  d e l i v e r  c r e d i t  c a r d  p r o d u c t s ,
# t e x t  e x t r a c t i o n  u s i n g  M L  m e t h o d o l o g y .
# L o o k i n g  t o  w o r k  i n  c h a l l e n g i n g  e n v i r o n m e n t
# w h e r e  m y  s k i l l s  c a n  b e  l e v e r a g e d .
# E d u c a t i o n
# P o s t  G r a d u a t e  P r o g r a m  i n  A r t i f i c i a l
# I n t e l l i g e n c e  &  M a c h i n e  L e a r n i n g .
# G r e a t  L a k e s ,  C h e n n a i  i n  c o l l a b o r a t i o n  w i t h
# T h e  U n i v e r s i t y  o f  T e x a s ,  A u s t i n
# D e c e m b e r  2 0 2 1
# B a c h e l o r  o f  E n g i n e e r i n g  i n  c o m p u t e r
# s c i e n c e .
# E r o d e  S e n g u n t h a r  E n g i n e e r i n g  c o l l e g e ,
# E r o d e ,  I n d i a
# M a y  2 0 0 5
# W o r k  E x p e r i e n c e
# Kavipriya Kandavel
# 1 1 8 8 3  S p r i n g f i e l d  L n ,  F i s h e r s ,  I N  -  4 6 0 3 8
# i t s k a v i p r i y a k @ g m a i l . c o m
# P h :  4 6 3 - 6 7 3 - 7 1 6 6' metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-10-27T18:53:53+00:00', 'title': 'Kavipriya Kandavel - AIML Engineer_2025', 'moddate': '2025-10-27T18:53:51+00:00', 'keywords': 'DAGzQ-IZ9XU,BAEsngv9QRE,0', 'author': 'Kavipriya Kandavel', 'source': 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Kavipriya Kandavel - AIML Engineer_2025.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}

# %%
from typing import List, Any
from langchain_text_splitters import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
import numpy as np
# from src.data_loader import load_all_documents

class EmbeddingPipeline:
    def __init__(self, model_name: str = "all-MiniLM-L6-v2", chunk_size: int = 1000, chunk_overlap: int = 100):
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.model = SentenceTransformer(model_name)
        print(f"[INFO] Loaded embedding model: {model_name}")

    def chunk_documents(self, documents: List[Any]) -> List[Any]:
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=self.chunk_size,
            chunk_overlap=self.chunk_overlap,
            length_function=len,
            separators=["\n\n", "\n", " ", "", "\t"]
        )
        chunks = splitter.split_documents(documents)
        print(f"[INFO] Split {len(documents)} documents into {len(chunks)} chunks.")
        return chunks

    def embed_chunks(self, chunks: List[Any]) -> np.ndarray:
        texts = [chunk.page_content for chunk in chunks]
        print(f"[INFO] Generating embeddings for {len(texts)} chunks...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"[INFO] Embeddings shape: {embeddings.shape}")
        return embeddings

# Example usage
if __name__ == "__main__":

    docs = load_all_documents("data")
    # docs = list(documents)
    emb_pipe = EmbeddingPipeline()
    chunks = emb_pipe.chunk_documents(docs)
    embeddings = emb_pipe.embed_chunks(chunks)
    print("[INFO] Example embedding:", embeddings[0] if len(embeddings) > 0 else None)
# Out:
# [DEBUG] Data path: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data
# [DEBUG] Found 2 PDF files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Kavipriya Kandavel - AIML Engineer_2025.pdf', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Vijayalakshmi-Aadhaar.pdf']
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loaded 5 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Loaded 1 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Found 0 TXT files: []
# [DEBUG] Found 0 CSV files: []
# [DEBUG] Found 0 Excel files: []
# [DEBUG] Found 1 Word files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\zData Scientist Job Description.docx']
# [DEBUG] Loading Word: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx
# [ERROR] Failed to load Word C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx: No module named 'docx2txt'
# [DEBUG] Found 0 JSON files: []
# [DEBUG] Found 2 JPG files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\commerical.jpg', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\decisions.jpg']
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# [DEBUG] Total loaded documents: 8
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 533.41it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INFO] Loaded embedding model: all-MiniLM-L6-v2
# [INFO] Split 8 documents into 33 chunks.
# [INFO] Generating embeddings for 33 chunks...
# Batches: 100%|██████████| 2/2 [00:00<00:00,  2.03it/s]
# [INFO] Embeddings shape: (33, 384)
# [INFO] Example embedding: [-3.10981311e-02 -5.14106601e-02  4.62562218e-02 -3.31610069e-02
#  -2.76693702e-02  6.15289174e-02  4.20717010e-03  1.41315032e-02
#  -2.90931351e-02 -8.52834061e-03 -2.11076215e-02 -1.23546235e-02
#   6.67023361e-02  8.72620642e-02 -5.78499734e-02  4.82556149e-02
#  -1.05137927e-02  4.33315858e-02 -8.71665403e-02 -1.66938491e-02
#   5.95734902e-02  4.82377857e-02  5.34548541e-04  1.06225780e-03
#  -8.24130625e-02  1.25028240e-02  2.80261207e-02  4.92600016e-02
#   8.59267358e-03 -1.03775449e-01  8.64520818e-02  8.70454386e-02
#   1.79333631e-02 -4.09216285e-02  4.72988673e-02  3.47332694e-02
#  -2.60278117e-03 -1.12480167e-02  3.73772457e-02  3.95998992e-02
#   9.32608172e-03 -1.02492504e-01  5.05215116e-02  5.47448061e-02
#   4.51269187e-02 -1.39541430e-02  4.04830575e-02 -6.28431439e-02
#  -7.43846968e-02 -3.84880826e-02 -3.07338126e-02 -1.59780309e-02
#  -3.91715840e-02  1.58662833e-02  1.59302857e-02 -2.51384508e-02
#  -3.32849752e-03  1.50043303e-02  4.40635979e-02  1.07531734e-01
#   3.84813268e-03  3.44721042e-03 -4.45314012e-02 -3.51322442e-02
#   1.04220081e-02 -6.58971146e-02 -6.12326339e-02  6.84452578e-02
#  -1.00393392e-01 -4.75164354e-02  5.36725037e-02  4.74513508e-02
#  -5.48204072e-02  5.70814125e-02 -2.92344466e-02 -3.94693576e-03
#  -8.67494103e-03 -1.34292040e-02 -2.87404619e-02 -5.01538813e-02]

# %%
import os
import faiss
import numpy as np
import pickle
from typing import List, Any
from sentence_transformers import SentenceTransformer
# from src.embedding import EmbeddingPipeline

class FaissVectorStore:
    def __init__(self, persist_dir: str = "faiss_store", embedding_model: str = "all-MiniLM-L6-v2", chunk_size: int = 1000, chunk_overlap: int = 100):
        self.persist_dir = persist_dir
        os.makedirs(self.persist_dir, exist_ok=True)
        self.index = None
        self.metadata = []
        self.embedding_model = embedding_model
        self.model = SentenceTransformer(embedding_model)
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        print(f"[INFO] Loaded embedding model: {embedding_model}")

    def build_from_documents(self, documents: List[Any]):
        print(f"[INFO] Building vector store from {len(documents)} raw documents...")
        emb_pipe = EmbeddingPipeline(model_name=self.embedding_model, chunk_size=self.chunk_size, chunk_overlap=self.chunk_overlap)
        chunks = emb_pipe.chunk_documents(documents)
        embeddings = emb_pipe.embed_chunks(chunks)
        metadatas = [{"text": chunk.page_content} for chunk in chunks]
        self.add_embeddings(np.array(embeddings).astype('float32'), metadatas)
        self.save()
        print(f"[INFO] Vector store built and saved to {self.persist_dir}")

    def add_embeddings(self, embeddings: np.ndarray, metadatas: List[Any] = None):
        dim = embeddings.shape[1]
        print("embeddings shape[1]:", dim)
        if self.index is None:
            self.index = faiss.IndexFlatL2(dim)
        self.index.add(embeddings)
        if metadatas:
            self.metadata.extend(metadatas)
        print(f"[INFO] Added {embeddings.shape[0]} vectors to Faiss index.")

    def save(self):
        faiss_path = os.path.join(self.persist_dir, "faiss.index")
        meta_path = os.path.join(self.persist_dir, "metadata.pkl")
        faiss.write_index(self.index, faiss_path)
        with open(meta_path, "wb") as f:
            pickle.dump(self.metadata, f)
        print(f"[INFO] Saved Faiss index and metadata to {self.persist_dir}")

    def load(self):
        faiss_path = os.path.join(self.persist_dir, "faiss.index")
        meta_path = os.path.join(self.persist_dir, "metadata.pkl")
        self.index = faiss.read_index(faiss_path)
        with open(meta_path, "rb") as f:
            self.metadata = pickle.load(f)
        print(f"[INFO] Loaded Faiss index and metadata from {self.persist_dir}")

    def search(self, query_embedding: np.ndarray, top_k: int = 5):
        D, I = self.index.search(query_embedding, top_k)
        results = []
        for idx, dist in zip(I[0], D[0]):
            meta = self.metadata[idx] if idx < len(self.metadata) else None
            results.append({"index": idx, "distance": dist, "metadata": meta})
        return results

    def query(self, query_text: str, top_k: int = 5):
        print(f"[INFO] Querying vector store for: '{query_text}'")
        query_emb = self.model.encode([query_text]).astype('float32')
        return self.search(query_emb, top_k=top_k)

# Example usage
if __name__ == "__main__":
    # from data_loader import load_all_documents
    docs = load_all_documents("data")
    # docs = list("data")
    store = FaissVectorStore("faiss_store")
    store.build_from_documents(docs)
    store.load()
    print(store.query("Representative in Kuwait", top_k=3))
# Out:
# [DEBUG] Data path: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data
# [DEBUG] Found 2 PDF files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Kavipriya Kandavel - AIML Engineer_2025.pdf', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\Vijayalakshmi-Aadhaar.pdf']
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loaded 5 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Kavipriya Kandavel - AIML Engineer_2025.pdf
# [DEBUG] Loading PDF: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Loaded 1 PDF docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\Vijayalakshmi-Aadhaar.pdf
# [DEBUG] Found 0 TXT files: []
# [DEBUG] Found 0 CSV files: []
# [DEBUG] Found 0 Excel files: []
# [DEBUG] Found 1 Word files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\zData Scientist Job Description.docx']
# [DEBUG] Loading Word: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx
# [ERROR] Failed to load Word C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\zData Scientist Job Description.docx: No module named 'docx2txt'
# [DEBUG] Found 0 JSON files: []
# [DEBUG] Found 2 JPG files: ['C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\commerical.jpg', 'C:\\Users\\sakth\\PyCharmMiscProject\\RAG Pipeline\\data\\decisions.jpg']
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\commerical.jpg
# [DEBUG] Loading JPG: C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# Warning: No languages specified, defaulting to English.
# [DEBUG] Loaded 1 JPG docs from C:\Users\sakth\PyCharmMiscProject\RAG Pipeline\data\decisions.jpg
# [DEBUG] Total loaded documents: 8
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 460.67it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INFO] Loaded embedding model: all-MiniLM-L6-v2
# [INFO] Building vector store from 8 raw documents...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 472.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INFO] Loaded embedding model: all-MiniLM-L6-v2
# [INFO] Split 8 documents into 33 chunks.
# [INFO] Generating embeddings for 33 chunks...
# Batches: 100%|██████████| 2/2 [00:00<00:00,  2.04it/s]
# [INFO] Embeddings shape: (33, 384)
# embeddings shape[1]: 384
# [INFO] Added 33 vectors to Faiss index.
# [INFO] Saved Faiss index and metadata to faiss_store
# [INFO] Vector store built and saved to faiss_store
# [INFO] Loaded Faiss index and metadata from faiss_store
# [INFO] Querying vector store for: 'Representative in Kuwait'
# [{'index': np.int64(27), 'distance': np.float32(0.90323853), 'metadata': {'text': 'Summarize all the Commercial Agencies registration in a table while providing the commercial agency, its country, representative in Kuwait, agency registration number, and dates\n\nShow thinking ¥\n\nBased on the Official Gazette of Kuwait (Kuwait Al Your), Issue No. 1674, the following Commercial Agencies registrations were announced:'}}, {'index': np.int64(28), 'distance': np.float32(1.0275153), 'metadata': {'text': 'Commercial Agencies registrations were announced: ‘Commercial Agency Dogusan Insaat Ticaret AS. Bendalis G